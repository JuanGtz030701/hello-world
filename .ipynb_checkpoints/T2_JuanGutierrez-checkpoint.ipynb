# %% [markdown]
# ## Este es un nuevo cuaderno de Jupyter que ese agregó en el repositorio

# %% [markdown]
# Lista de compras de despensa:
# 1. Arroz
# 2. Tomate
# 3. Yogurth
# 4. Cebolla
# 5. Cilantro
